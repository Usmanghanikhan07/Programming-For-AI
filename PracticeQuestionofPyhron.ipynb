# %%
# Some Practice Questions

#Question 1 : Write a Program to input 2 numbers and print their sum

num1 = float(input("Enter 1st number : "))
num2 = float(input("Enter 2nd number : "))

Sum = num1 + num2

print("Sum :", Sum)
# Out:
# Enter 1st number :  2
# Enter 2nd number :  3
# Sum : 5.0

# %%
# Question 2 : Write  to input side of a Square and print its area

SideofSqr = float(input("Enter Number : "))
SqaureofArea = 2*(SideofSqr) 
print("Area of Square : ",SqaureofArea )
# Out:
# Enter Number :  3
# Area of Square :  6.0

# %%
# Question 3 : Write  to input 2 floating point numbers and print their average

num1 = float(input("Enter 1st number : "))
num2 = float(input("Enter 2nd number : "))

Average = ((num1 + num2)/2)

print("Average : ", Average)
# Out:
# Enter 1st number :  3.5
# Enter 2nd number :  4.5
# Average :  4.0

# %%
# Question 3 : Write  to input 2 int numbers, a and b. print True if a is greater than or equal to b. if not print False

a = float(input("Enter 1st number : "))
b  = float(input("Enter 2nd number : "))

print("If a>= b then True, otherwise False \n", a>=b)
# Out:
# Enter 1st number :  3
# Enter 2nd number :  5
# If a>= b then True, otherwise False
#  False
