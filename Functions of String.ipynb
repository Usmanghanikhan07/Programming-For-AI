# %%
#Functions Of String

# endswith() Functions

str = "I am Machine Lerning Engineer" # return true if string ends with substr
print(str.endswith("er"))
# Out:
# True

# %%
str = "I am Machine Lerning Engineer" # return true if string ends with substr
print(str.endswith("gg"))
# Out:
# False

# %%
# Capitalize() Functions

str = "i am Machine Lerning Engineer" # Capitalize 1st character
str = print(str.capitalize())
# Out:
# I am machine lerning engineer

# %%
# replace() Functions

str = "i am Machine Lerning Engineer" # replace all occurance of old
str = print(str.replace("Machine","Deep"))
# Out:
# i am Deep Lerning Engineer

# %%
# find() Functions

str = "i am Machine Lerning Engineer" # return 1st index of 1st occurrer
str = print(str.find("M")) #Find index
# Out:
# 5

# %%
# count() Functions

str = "i am Machine Lerning Engineer" # counts the occurrence of substr
str = print(str.count("e"))
# Out:
# 4
