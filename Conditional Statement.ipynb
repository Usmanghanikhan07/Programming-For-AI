# %%
# COnditional Statement 

age = 3

if(age >= 18):
    print("can you apply for vote")

else:
    print("No eligible for vote")
# Out:
# No eligible for vote

# %%
light = "Pink"

if(light == "Red"):
    print("Stop")

elif(light == "Green"):
    print("Go")

elif(light == "Yellow"):
    print("Look")

else:
    print("light is broken")
# Out:
# light is broken

# %%
Num = 10

if(Num == 10):
    print("10 Equal to 10")

if(Num >= 3):
    print("3 less than or Equal to 10")

if(Num > 8):
    print("8 less than to 10")
    
else:
    print("Invalid Number")
# Out:
# 10 Equal to 10
# 3 greater than or Equal to 10
# 3 less than to 10

# %%
#========= Grade Students based on marks ===========

marks = int(input("Enter your Marks : "))

if(marks >= 90):
    print("Grade A")
    
elif(marks < 90 and marks >= 80):
    print("Grade B")
        
elif(marks < 80 and marks >= 70):
    print("Grade C")
        
elif(marks < 70 and marks >= 60):
    print("Grade D")
    
elif(marks < 60 and marks >= 50):
    print("Grade E")

else:
    print("Grade F")
# Out:
# Enter your Marks :  49
# Grade F

# %%
# Nesting Conditional Statement 

age = int(input("Enter your Age : "))

if(age >= 18):
    if(age >= 70):
         print("Con't drive") 
    else:
        print("You Can Drive")
else:
    print("Can't Drive")
# Out:
# Enter your Age :  66
# You Can Drive
