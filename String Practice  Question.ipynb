# %%
# String Practice Questions

# %%
#1 Write to input user's first name and print its length

name = input("Enter your name : ")
print (len(name))
# Out:
# Enter your name :  Usman
# 5

# %%
#2 Write to find the accurence of "$" in a string

dollar = "I am $$$"
print(count("$"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 #2 Write to find the accurence of "$" in a string
#       2
#       3 dollar = "I am $$$"
# ----> 4 print(count("$"))
#
# NameError: name 'count' is not defined
