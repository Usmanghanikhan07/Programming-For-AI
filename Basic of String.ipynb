# %%
# String basic Initialization

str1 = "UGK"
str2 = 'UGK'
str3 = """UGK"""

str4 = "MY name is UGK's "

print(str1)
print(str2)
print(str3)
print(str4)
# Out:
# UGK
# UGK
# UGK
# MY name is UGK's

# %%
a = "My name is UGK.\nI am from SHQ"
print(a)
# Out:
# My name is UGK.
# I am from SHQ

# %%
# Basic operation of String

str5 = "Usman "
str6 = "Ghani Khan"

Final_String = str5 + " " + str6 # Add tow String

print(Final_String)
print (len(Final_String))
# Out:
# Usman  Ghani Khan
# 17

# %%
# H ow to find Idexing of the String

name = "Usman Ghani Khan"
print(name[2])
# Out:
# m

# %%
# Slicing Concept with some example

str1 = "UGK IS NAME"
print(str1[0:2])
print(str1[4:6]),"\n"
print(str1[7:11])
# Out:
# UG
# IS
# NAME

# %%
# Slicing Concept with some example
# Negative indexing

str1 = "Apple"
print(str1[-3:-1])
print(str1[-5:-2])
# Out:
# pl
# App
