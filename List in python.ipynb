# %%
#List in python

marks = [1,2,3,4,5]
print (marks[1:3])
# Out:
# [2, 3]

# %%
marks = [1,2,3,4,5]
print (marks[1:])
# Out:
# [2, 3, 4, 5]

# %%
marks = [1,2,3,4,5]
print (marks[:3])
# Out:
# [1, 2, 3]

# %%
marks = [1,2,3,4,5]
print (marks[-3:-1])
# Out:
# [3, 4]

# %%
marks = [1,2,3,4,5]
print (marks[:-1])
# Out:
# [1, 2, 3, 4]

# %%
marks = [1,2,3,4,5]
print (marks[-3:])
# Out:
# [3, 4, 5]
