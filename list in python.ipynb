# %%
# Lists in python different examoples

# %%
marks = [1, 3, 4, 5, 6, 7]

print(marks)
print(marks[0])
print(len(marks))
# Out:
# [1, 3, 4, 5, 6, 7]
# 1
# 6

# %%
Student = ["Student", 1, "Dehli"]

print(Student)
# Out:
# ['Student', 1, 'Dehli']
